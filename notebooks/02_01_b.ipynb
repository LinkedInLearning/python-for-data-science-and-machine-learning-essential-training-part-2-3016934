# %% [markdown]
# # Simple linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import sklearn

from pylab import rcParams

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 10,8

# %%
rooms = 2*np.random.rand(100,1)+3
rooms[0:10]
# Out:
# array([[4.32332494],
#        [3.85617895],
#        [4.44178214],
#        [3.63455753],
#        [3.72866936],
#        [3.31141164],
#        [3.45290778],
#        [4.01263366],
#        [3.37896368],
#        [3.6926512 ]])

# %%
price = 265 + 6*rooms + abs(np.random.randn(100, 1))
price[0:10]
# Out:
# array([[292.7389157 ],
#        [288.71863572],
#        [292.32740093],
#        [287.99596628],
#        [288.08042645],
#        [285.24021509],
#        [286.13675243],
#        [289.15000761],
#        [286.50050224],
#        [288.34139164]])

# %%
import matplotlib.pyplot as plt

plt.plot(rooms, price, 'r^')
plt.xlabel("# of Rooms, 2024 Average")
plt.ylabel("2024 Average Home, $1000s USD")
plt.show()

# %%
X = rooms
y = price

LinReg = LinearRegression()
LinReg.fit(X,y)
print(LinReg.intercept_,LinReg.coef_)
# Out:
# [265.80271057] [[6.00441779]]

# %% [markdown]
# *Simple Algebra*
# - y = mx + b
# - b = intercept = 265.8
#
# *Estimated Coefficients*
# - LinReg.coef_ = [6.004] Estimated coefficients for the terms in the linear regression problem.

# %%
print(LinReg.score(X,y))
# Out:
# 0.9672370124112972
